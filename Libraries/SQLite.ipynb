# %%
import sqlite3

connection = sqlite3.connect("example.db")
cursor = connection.cursor()

cursor.execute(''' create table if not exists employees(
               id Integer Primary key,
               name Text Not Null,
               age Integer,
               department text) ''')
connection.commit()

# %%
cursor.execute('''select *from employees''')

# %%
cursor.execute('''
Insert Into employees(name,age,department) values('krish',32,'Data scientist')''')
cursor.execute('''
Insert Into employees(name,age,department) values('Bob',25,'Engineering')''')
cursor.execute('''
Insert Into employees(name,age,department) values('charlie',35,'Finance')''')
connection.commit()

# %%
cursor.execute('Select *from employees')
rows = cursor.fetchall()
for row in rows:
  print(row)
# Out:
# (1, 'krish', 32, 'Data scientist')
# (2, 'krish', 32, 'Data scientist')
# (3, 'Bob', 25, 'Engineering')
# (4, 'krish', 32, 'Data scientist')
# (5, 'Bob', 25, 'Engineering')
# (6, 'charlie', 35, 'Finance')
# (7, 'krish', 32, 'Data scientist')
# (8, 'Bob', 25, 'Engineering')
# (9, 'charlie', 35, 'Finance')
# (10, 'krish', 32, 'Data scientist')
# (11, 'Bob', 25, 'Engineering')
# (12, 'charlie', 35, 'Finance')
# (13, 'krish', 32, 'Data scientist')
# (14, 'Bob', 25, 'Engineering')
# (15, 'charlie', 35, 'Finance')

# %%
import sqlite3

connection = sqlite3.connect("sales_data.db")
cursor = connection.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    date TEXT NOT NULL,
    product TEXT NOT NULL,
    sales INTEGER,
    region TEXT
)
""")

sales_data = [
    ('2023-01-20', 'Product A', 300, 'North'),
    ('2023-01-21', 'Product B', 450, 'South'),
    ('2023-01-22', 'Product A', 200, 'East'),
    ('2023-01-23', 'Product C', 500, 'West')
]

cursor.executemany(
    "INSERT INTO sales (date, product, sales, region) VALUES (?, ?, ?, ?)",
    sales_data
)

connection.commit()
connection.close()
